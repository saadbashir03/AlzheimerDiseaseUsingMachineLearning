# %% [markdown]
# ## Connection to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # importing data

# %%
from pathlib import Path
import pandas as pd

# Replace with the actual path to your Excel file
file_path = "/content/drive/MyDrive/LSBU/ML Resit/diagonise .xlsx"

# Using Path to handle file paths
file = Path(file_path)

# Check if the file exists before attempting to read
if file.is_file():
    df1 = pd.read_excel(file)
    print("File read successfully into a DataFrame.")
else:
    print(f"File not found at {file_path}. Please check the file path.")
# Out:
# File read successfully into a DataFrame.

# %%
df1.columns
# Out:
# Index(['RID', 'Test_data', 'Diagnosis', 'FDG_PET', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %%
columns_to_drop = ["Unnamed: 4", 'Unnamed: 5', 'Unnamed: 6']
df1.drop(columns=columns_to_drop, inplace=True)

# %%
df1
# Out:
#        RID  Test_data Diagnosis  FDG_PET
# 0        2          0        CN  1.36926
# 1        3          0        AD  1.09079
# 2        4          1      LMCI      NaN
# 3        5          0        CN  1.29799
# 4        6          0      LMCI      NaN
# ...    ...        ...       ...      ...
# 1732  5287          0       SMC  1.58312
# 1733  5295          0       SMC  1.16317
# 1734  5296          0       SMC  1.42926
# 1735  4264          1        CN      NaN
# 1736  4740          0        AD      NaN
#
# [1737 rows x 4 columns]

# %%
import pandas as pd
from pathlib import Path

# Specify the path to your Excel file
file_path = "/content/drive/MyDrive/LSBU/ML Resit/cognitive score.xlsx"

# Convert the file path string to a Path object for better path handling
excel_file = Path(file_path)

# Check if the Excel file exists to prevent runtime errors
if excel_file.exists():
    # Read the Excel file into a DataFrame
    df2 = pd.read_excel(excel_file)
    print("Excel file successfully loaded into DataFrame.")
else:
    print(f"Error: The file at {file_path} does not exist. Please check the path.")

# Display the DataFrame if it was successfully loaded
if 'df2' in locals():
    display(df2)
# Out:
# Excel file successfully loaded into DataFrame.
#        RID  Test_data  CDRSB  ADAS11  ADAS13  MMSE  RAVLT_immediate  \
# 0        2          0    0.0   10.67   18.67    28             44.0
# 1        3          0    4.5   22.00   31.00    20             22.0
# 2        4          1    1.0   14.33   21.33    27             37.0
# 3        5          0    0.0    8.67   14.67    29             37.0
# 4        6          0    0.5   18.67   25.67    25             30.0
# ...    ...        ...    ...     ...     ...   ...              ...
# 1732  5287          0    0.5    3.00    4.00    29             50.0
# 1733  5295          0    0.5   11.00   18.00    29             28.0
# 1734  5296          0    0.0    9.00   14.00    29             38.0
# 1735  4264          1    0.0    3.00    6.00    29             48.0
# 1736  4740          0    1.5   29.00   41.00    22              8.0
#
#       RAVLT_learning  RAVLT_forgetting  RAVLT_perc_forgetting
# ...

# %%
import pandas as pd
from pathlib import Path

# Set the path to your Excel file
file_path = "/content/drive/MyDrive/LSBU/ML Resit/CSI_7_MAL_2324_CW_resit_data (1).xlsx"

# Use Path for better file path handling
excel_path = Path(file_path)

# Check if the file exists to avoid errors
if excel_path.is_file():
    # Read the Excel file into a DataFrame
    df3 = pd.read_excel(excel_path)
    print("Data loaded successfully.")
else:
    print(f"File not found at: {file_path}")

# If the DataFrame was successfully created, display it
if 'df3' in locals():
    display(df3)  # This works well in Jupyter Notebooks; use print(resit_data_df) in other environments
# Out:
# Data loaded successfully.
#        RID  Test_data   Age  Gender  Year_education        Ethnicity   Race  \
# 0        2          0  74.3    Male              16  Not Hisp/Latino  White
# 1        3          0  81.3    Male              18  Not Hisp/Latino  White
# 2        4          1  67.5    Male              10      Hisp/Latino  White
# 3        5          0  73.7    Male              16  Not Hisp/Latino  White
# 4        6          0  80.4  Female              13  Not Hisp/Latino  White
# ...    ...        ...   ...     ...             ...              ...    ...
# 1732  5287          0  78.9  Female              16  Not Hisp/Latino  White
# 1733  5295          0  75.5  Female              15  Not Hisp/Latino  White
# 1734  5296          0  69.3    Male              14  Not Hisp/Latino  White
# 1735  4264          1  74.1  Female              18  Not Hisp/Latino  White
# 1736  4740          0  88.3    Male              12  Not Hisp/Latino  White
#
# ...

# %% [markdown]
# ## Concatenated three Dataframe

# %%
import pandas as pd

# Assuming df1, df2, and df3 are your three dataframes

# Concatenate the dataframes based on common columns RID and Test_data
concatenated_df = pd.concat([df1, df2, df3],axis=1)

concatenated_df
# Out:
#        RID  Test_data Diagnosis  FDG_PET   RID  Test_data  CDRSB  ADAS11  \
# 0        2          0        CN  1.36926     2          0    0.0   10.67
# 1        3          0        AD  1.09079     3          0    4.5   22.00
# 2        4          1      LMCI      NaN     4          1    1.0   14.33
# 3        5          0        CN  1.29799     5          0    0.0    8.67
# 4        6          0      LMCI      NaN     6          0    0.5   18.67
# ...    ...        ...       ...      ...   ...        ...    ...     ...
# 1732  5287          0       SMC  1.58312  5287          0    0.5    3.00
# 1733  5295          0       SMC  1.16317  5295          0    0.5   11.00
# 1734  5296          0       SMC  1.42926  5296          0    0.0    9.00
# 1735  4264          1        CN      NaN  4264          1    0.0    3.00
# 1736  4740          0        AD      NaN  4740          0    1.5   29.00
#
#       ADAS13  MMSE  ...  \
# 0      18.67    28  ...
# 1      31.00    20  ...
# ...

# %%
concatenated_df.columns
# Out:
# Index(['RID', 'Test_data', 'Diagnosis', 'FDG_PET', 'RID', 'Test_data', 'CDRSB',
#        'ADAS11', 'ADAS13', 'MMSE',
#        ...
#        'Cortical Thickness Standard Deviation of RightLingual',
#        'Volume (Cortical Parcellation) of RightMedialOrbitofrontal',
#        'Surface Area of RightMedialOrbitofrontal',
#        'Cortical Thickness Average of RightMedialOrbitofrontal',
#        'Cortical Thickness Standard Deviation of RightMedialOrbitofrontal',
#        'Volume (Cortical Parcellation) of RightMiddleTemporal',
#        'Surface Area of RightMiddleTemporal',
#        'Cortical Thickness Average of RightMiddleTemporal',
#        'Cortical Thickness Standard Deviation of RightMiddleTemporal',
#        'Volume (WM Parcellation) of FourthVentricle'],
#       dtype='object', length=375)

# %%
concatenated_df = concatenated_df.loc[:,~concatenated_df.columns.duplicated()]

concatenated_df
# Out:
#        RID  Test_data Diagnosis  FDG_PET  CDRSB  ADAS11  ADAS13  MMSE  \
# 0        2          0        CN  1.36926    0.0   10.67   18.67    28
# 1        3          0        AD  1.09079    4.5   22.00   31.00    20
# 2        4          1      LMCI      NaN    1.0   14.33   21.33    27
# 3        5          0        CN  1.29799    0.0    8.67   14.67    29
# 4        6          0      LMCI      NaN    0.5   18.67   25.67    25
# ...    ...        ...       ...      ...    ...     ...     ...   ...
# 1732  5287          0       SMC  1.58312    0.5    3.00    4.00    29
# 1733  5295          0       SMC  1.16317    0.5   11.00   18.00    29
# 1734  5296          0       SMC  1.42926    0.0    9.00   14.00    29
# 1735  4264          1        CN      NaN    0.0    3.00    6.00    29
# 1736  4740          0        AD      NaN    1.5   29.00   41.00    22
#
#       RAVLT_immediate  RAVLT_learning  ...  \
# 0                44.0             4.0  ...
# ...

# %%
test_df=concatenated_df

# %% [markdown]
# # Data Exploration

# %%
concatenated_df.shape
# Out:
# (1737, 371)

# %%
concatenated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1737 entries, 0 to 1736
# Columns: 371 entries, RID to Volume (WM Parcellation) of FourthVentricle
# dtypes: float64(17), int64(4), object(350)
# memory usage: 4.9+ MB

# %%
concatenated_df.head(10)
# Out:
#    RID  Test_data Diagnosis  FDG_PET  CDRSB  ADAS11  ADAS13  MMSE  \
# 0    2          0        CN  1.36926    0.0   10.67   18.67    28
# 1    3          0        AD  1.09079    4.5   22.00   31.00    20
# 2    4          1      LMCI      NaN    1.0   14.33   21.33    27
# 3    5          0        CN  1.29799    0.0    8.67   14.67    29
# 4    6          0      LMCI      NaN    0.5   18.67   25.67    25
# 5    7          1        AD      NaN    6.0   27.33   40.33    20
# 6    8          0        CN  1.27628    0.0    5.00    7.00    28
# 7   10          0        AD  1.11881    5.0   12.33   24.33    24
# 8   14          0        CN  1.25699    0.0    4.33    8.33    29
# 9   15          0        CN      NaN    0.0    7.00    9.00    29
#
#    RAVLT_immediate  RAVLT_learning  ...  \
# 0             44.0             4.0  ...
# 1             22.0             1.0  ...
# 2             37.0             7.0  ...
# 3             37.0             4.0  ...
# ...

# %%
concatenated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1737 entries, 0 to 1736
# Columns: 371 entries, RID to Volume (WM Parcellation) of FourthVentricle
# dtypes: float64(17), int64(4), object(350)
# memory usage: 4.9+ MB

# %%
concatenated_df.describe()
# Out:
#                RID    Test_data      FDG_PET        CDRSB       ADAS11  \
# count  1737.000000  1737.000000  1303.000000  1737.000000  1732.000000
# mean   2603.533679     0.199770     1.233933     1.639321    10.773672
# std    1926.356831     0.399942     0.154161     1.792005     6.657689
# min       2.000000     0.000000     0.697264     0.000000     0.000000
# 25%     759.000000     0.000000     1.141735     0.000000     6.000000
# 50%    2150.000000     0.000000     1.245480     1.000000     9.000000
# 75%    4546.000000     0.000000     1.336715     2.500000    14.000000
# max    5296.000000     1.000000     1.707170    10.000000    42.670000
#
#             ADAS13         MMSE  RAVLT_immediate  RAVLT_learning  \
# count  1723.000000  1737.000000      1731.000000     1731.000000
# mean     16.899008    27.173287        35.153091        4.177354
# std       9.584230     2.666661        12.464480        2.734129
# min       0.000000    18.000000         0.000000       -4.000000
# ...

# %%
concatenated_df.dtypes
# Out:
# RID                                                               int64
# Test_data                                                         int64
# Diagnosis                                                        object
# FDG_PET                                                         float64
# CDRSB                                                           float64
#                                                                  ...
# Volume (Cortical Parcellation) of RightMiddleTemporal            object
# Surface Area of RightMiddleTemporal                              object
# Cortical Thickness Average of RightMiddleTemporal                object
# Cortical Thickness Standard Deviation of RightMiddleTemporal     object
# Volume (WM Parcellation) of FourthVentricle                      object
# Length: 371, dtype: object

# %%
concatenated_df.columns
# Out:
# Index(['RID', 'Test_data', 'Diagnosis', 'FDG_PET', 'CDRSB', 'ADAS11', 'ADAS13',
#        'MMSE', 'RAVLT_immediate', 'RAVLT_learning',
#        ...
#        'Cortical Thickness Standard Deviation of RightLingual',
#        'Volume (Cortical Parcellation) of RightMedialOrbitofrontal',
#        'Surface Area of RightMedialOrbitofrontal',
#        'Cortical Thickness Average of RightMedialOrbitofrontal',
#        'Cortical Thickness Standard Deviation of RightMedialOrbitofrontal',
#        'Volume (Cortical Parcellation) of RightMiddleTemporal',
#        'Surface Area of RightMiddleTemporal',
#        'Cortical Thickness Average of RightMiddleTemporal',
#        'Cortical Thickness Standard Deviation of RightMiddleTemporal',
#        'Volume (WM Parcellation) of FourthVentricle'],
#       dtype='object', length=371)

# %% [markdown]
# ### Distribution of Gender

# %%
concatenated_df["Gender"].value_counts()
# Out:
# Male      957
# Female    780
# Name: Gender, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a figure and a set of subplots with a custom figure size
plt.figure(figsize=(8, 6))

# Create a count plot for the 'Gender' column in the concatenated_df DataFrame
gender_distribution_plot = sns.countplot(x='Gender', data=concatenated_df, palette='coolwarm')

# Set the title of the plot with a custom font size
gender_distribution_plot.set_title('Distribution of Gender', fontsize=16)

# Label the x-axis and y-axis with custom font sizes
gender_distribution_plot.set_xlabel('Gender', fontsize=14)
gender_distribution_plot.set_ylabel('Count', fontsize=14)

# Optimize layout and display the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-242-8d8b1196969b>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   gender_distribution_plot = sns.countplot(x='Gender', data=concatenated_df, palette='coolwarm')

# %%
import matplotlib.pyplot as plt

# Calculate the counts of each gender in the 'Gender' column
gender_counts = concatenated_df['Gender'].value_counts()

# Create a new figure with a specified figure size
plt.figure(figsize=(8, 6))

# Create a pie chart of the gender counts
# 'autopct' displays the percentage value using Python string formatting. Here, it's rounded to one decimal place.
# 'startangle' rotates the start of the pie chart by 140 degrees to change the pie chart's orientation.
pie_chart = plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightpink'])

# Set the title of the pie chart with a custom font size
plt.title('Distribution of Gender', fontsize=16)

# 'equal' aspect ratio ensures that the pie chart is drawn as a circle, maintaining the pie's symmetry
plt.axis('equal')

# Display the pie chart
plt.show()

# %%
value_counts = concatenated_df["Marital_status"].value_counts()

# Calculate total count
total_count = concatenated_df["Marital_status"].count()
percentages = (value_counts / total_count) * 100


# Format percentages with percentage symbol
percentages_with_symbol = percentages.apply(lambda x: "{:.2f}%".format(x))
print(percentages_with_symbol)
# Out:
# Married          75.42%
# Widowed          11.86%
# Divorced          8.64%
# Never married     3.68%
# Unknown           0.40%
# Name: Marital_status, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Initialize a matplotlib figure with a specified size
plt.figure(figsize=(8, 6))

# Create a count plot for the 'Marital_status' column in concatenated_df
# This will automatically count the frequency of each unique value in the 'Marital_status' column
marital_status_plot = sns.countplot(x='Marital_status', data=concatenated_df, palette='Set2')

# Set the title of the plot with an increased font size for better readability
marital_status_plot.set_title('Distribution of Marital Status', fontsize=16)

# Correct the x-axis label to accurately reflect the data being plotted
marital_status_plot.set_xlabel('Marital Status', fontsize=14)

# Set the y-axis label with an increased font size
marital_status_plot.set_ylabel('Count', fontsize=14)

# Display the plot
plt.show()
# Out:
# <ipython-input-245-678042a7eb1e>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   marital_status_plot = sns.countplot(x='Marital_status', data=concatenated_df, palette='Set2')

# %%
value_counts = concatenated_df["Ethnicity"].value_counts()

# Calculate total count
total_count = concatenated_df["Ethnicity"].count()
percentages = (value_counts / total_count) * 100


# Format percentages with percentage symbol
percentages_with_symbol = percentages.apply(lambda x: "{:.2f}%".format(x))
print(percentages_with_symbol)
# Out:
# Not Hisp/Latino    96.03%
# Hisp/Latino         3.34%
# Unknown             0.63%
# Name: Ethnicity, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
sns.countplot(x='Ethnicity', data=concatenated_df)
plt.title('Distribution of Ethnicity')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
sns.countplot(x='High_risk_ApoE4', data=concatenated_df)
plt.title("High Risk")
plt.xlabel('Risk')
plt.ylabel('Count')
plt.show()

# %%
# Create histogram using Seaborn
sns.histplot(concatenated_df['Age'], bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Set the aesthetic style of the plot
plt.style.use('seaborn-darkgrid')

# Initialize a matplotlib figure with a specified size for better visualization
plt.figure(figsize=(10, 7))
plt.hist(concatenated_df["Year_education"], bins=range(0, 23), edgecolor='black', color='cornflowerblue')

# Add a title and axis labels with specified font sizes for improved readability
plt.title('Distribution of Years of Education', fontsize=16)
plt.xlabel('Years of Education', fontsize=14)
plt.ylabel('Number of People', fontsize=14)
plt.show()
# Out:
# <ipython-input-250-35622a089783>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# #Data cleaning

# %% [markdown]
# ### finding missing values and fill it using mean value

# %%
concatenated_df.isnull().sum()
# Out:
# RID                                                               0
# Test_data                                                         0
# Diagnosis                                                         0
# FDG_PET                                                         434
# CDRSB                                                             0
#                                                                ...
# Volume (Cortical Parcellation) of RightMiddleTemporal             0
# Surface Area of RightMiddleTemporal                               0
# Cortical Thickness Average of RightMiddleTemporal                 0
# Cortical Thickness Standard Deviation of RightMiddleTemporal      0
# Volume (WM Parcellation) of FourthVentricle                       0
# Length: 371, dtype: int64

# %%
concatenated_df = concatenated_df.fillna(concatenated_df.mean())
#concatenated_df = concatenated_df.fillna(0)
# Out:
# <ipython-input-252-b53a297734b1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   concatenated_df = concatenated_df.fillna(concatenated_df.mean())

# %%
concatenated_df.isnull().sum()
# Out:
# RID                                                             0
# Test_data                                                       0
# Diagnosis                                                       0
# FDG_PET                                                         0
# CDRSB                                                           0
#                                                                ..
# Volume (Cortical Parcellation) of RightMiddleTemporal           0
# Surface Area of RightMiddleTemporal                             0
# Cortical Thickness Average of RightMiddleTemporal               0
# Cortical Thickness Standard Deviation of RightMiddleTemporal    0
# Volume (WM Parcellation) of FourthVentricle                     0
# Length: 371, dtype: int64

# %% [markdown]
# ### checking and removing duplicate entries

# %%
dup_rows = concatenated_df[concatenated_df.duplicated()]

# Display duplicate entries
print("Duplicate Entries:")
print(dup_rows)

# Remove duplicate entries
concatenated_df = concatenated_df.drop_duplicates()

# Save cleaned dataset
concatenated_df.to_csv('cleaned_dataset.csv', index=False)
# Out:
# Duplicate Entries:
# Empty DataFrame
# ...

# %%
concatenated_df['Diagnosis'].value_counts()
# Out:
# LMCI    562
# CN      417
# AD      342
# EMCI    310
# SMC     106
# Name: Diagnosis, dtype: int64

# %% [markdown]
# ### Outlier Detection and Treatment:

# %%
import numpy as np

z_scores = (concatenated_df - concatenated_df.mean()) / concatenated_df.std()

# Define threshold for outlier detection (e.g., z-score > 3 or < -3)
threshold = 3

# Find outliers
outliers = concatenated_df[np.abs(z_scores) > threshold]
outliers
# Out:
# <ipython-input-256-fea62f1d7406>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   z_scores = (concatenated_df - concatenated_df.mean()) / concatenated_df.std()
# <ipython-input-256-fea62f1d7406>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   z_scores = (concatenated_df - concatenated_df.mean()) / concatenated_df.std()
#       RID  Test_data Diagnosis  FDG_PET  CDRSB  ADAS11  ADAS13  MMSE  \
# 0     NaN        NaN       NaN      NaN    NaN     NaN     NaN   NaN
# ...

# %% [markdown]
# ### Catagorical data into numeric

# %%
concatenated_df.dtypes
# Out:
# RID                                                               int64
# Test_data                                                         int64
# Diagnosis                                                        object
# FDG_PET                                                         float64
# CDRSB                                                           float64
#                                                                  ...
# Volume (Cortical Parcellation) of RightMiddleTemporal            object
# Surface Area of RightMiddleTemporal                              object
# Cortical Thickness Average of RightMiddleTemporal                object
# Cortical Thickness Standard Deviation of RightMiddleTemporal     object
# Volume (WM Parcellation) of FourthVentricle                      object
# Length: 371, dtype: object

# %%
concatenated_df["Diagnosis"]
# Out:
# 0         CN
# 1         AD
# 2       LMCI
# 3         CN
# 4       LMCI
#         ...
# 1732     SMC
# 1733     SMC
# 1734     SMC
# 1735      CN
# 1736      AD
# Name: Diagnosis, Length: 1737, dtype: object

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder


# Initialize label encoder
label_encoder = LabelEncoder()

# Encode categorical column
concatenated_df['Diagnosis'] = label_encoder.fit_transform(concatenated_df['Diagnosis'])
concatenated_df['Diagnosis']
# Out:
# 0       1
# 1       0
# 2       3
# 3       1
# 4       3
#        ..
# 1732    4
# 1733    4
# 1734    4
# 1735    1
# 1736    0
# Name: Diagnosis, Length: 1737, dtype: int64

# %%
concatenated_df['Gender'] = label_encoder.fit_transform(concatenated_df['Gender'])
concatenated_df['Gender']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 1732    0
# 1733    0
# 1734    1
# 1735    0
# 1736    1
# Name: Gender, Length: 1737, dtype: int64

# %%
concatenated_df['Year_education'] = label_encoder.fit_transform(concatenated_df['Year_education'])
concatenated_df['Year_education']
# Out:
# 0       11
# 1       13
# 2        5
# 3       11
# 4        8
#         ..
# 1732    11
# 1733    10
# 1734     9
# 1735    13
# 1736     7
# Name: Year_education, Length: 1737, dtype: int64

# %%
concatenated_df['Ethnicity'] = label_encoder.fit_transform(concatenated_df['Ethnicity'])
concatenated_df['Ethnicity']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 1732    1
# 1733    1
# 1734    1
# 1735    1
# 1736    1
# Name: Ethnicity, Length: 1737, dtype: int64

# %%
concatenated_df['Race'] = label_encoder.fit_transform(concatenated_df['Race'])
concatenated_df['Race']
# Out:
# 0       7
# 1       7
# 2       7
# 3       7
# 4       7
#        ..
# 1732    7
# 1733    7
# 1734    7
# 1735    7
# 1736    7
# Name: Race, Length: 1737, dtype: int64

# %%
concatenated_df['Marital_status'] = label_encoder.fit_transform(concatenated_df['Marital_status'])
concatenated_df['Marital_status']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1732    1
# 1733    1
# 1734    1
# 1735    0
# 1736    1
# Name: Marital_status, Length: 1737, dtype: int64

# %%
concatenated_df.isnull().sum()
# Out:
# RID                                                             0
# Test_data                                                       0
# Diagnosis                                                       0
# FDG_PET                                                         0
# CDRSB                                                           0
#                                                                ..
# Volume (Cortical Parcellation) of RightMiddleTemporal           0
# Surface Area of RightMiddleTemporal                             0
# Cortical Thickness Average of RightMiddleTemporal               0
# Cortical Thickness Standard Deviation of RightMiddleTemporal    0
# Volume (WM Parcellation) of FourthVentricle                     0
# Length: 371, dtype: int64

# %% [markdown]
# ### converting object into float

# %%
object_columns = concatenated_df.select_dtypes(include=['object']).columns.tolist()

# %%
# Convert object type columns to float
for col in object_columns:
    concatenated_df[col] = pd.to_numeric(concatenated_df[col], errors='coerce')

# %%
concatenated_df.dtypes
# Out:
# RID                                                               int64
# Test_data                                                         int64
# Diagnosis                                                         int64
# FDG_PET                                                         float64
# CDRSB                                                           float64
#                                                                  ...
# Volume (Cortical Parcellation) of RightMiddleTemporal           float64
# Surface Area of RightMiddleTemporal                             float64
# Cortical Thickness Average of RightMiddleTemporal               float64
# Cortical Thickness Standard Deviation of RightMiddleTemporal    float64
# Volume (WM Parcellation) of FourthVentricle                     float64
# Length: 371, dtype: object

# %%
concatenated_df.select_dtypes(include=['object']).columns.tolist()
# Out:
# []

# %%
concatenated_df.isnull().sum()
# Out:
# RID                                                              0
# Test_data                                                        0
# Diagnosis                                                        0
# FDG_PET                                                          0
# CDRSB                                                            0
#                                                                 ..
# Volume (Cortical Parcellation) of RightMiddleTemporal           16
# Surface Area of RightMiddleTemporal                             16
# Cortical Thickness Average of RightMiddleTemporal               16
# Cortical Thickness Standard Deviation of RightMiddleTemporal    16
# Volume (WM Parcellation) of FourthVentricle                     16
# Length: 371, dtype: int64

# %% [markdown]
# ## Filling the missing value

# %%
# concatenated_df = concatenated_df.fillna(concatenated_df.mean())
concatenated_df = concatenated_df.fillna(0)# Simple/Impute/r
concatenated_df.isnull().sum()
# Out:
# RID                                                             0
# Test_data                                                       0
# Diagnosis                                                       0
# FDG_PET                                                         0
# CDRSB                                                           0
#                                                                ..
# Volume (Cortical Parcellation) of RightMiddleTemporal           0
# Surface Area of RightMiddleTemporal                             0
# Cortical Thickness Average of RightMiddleTemporal               0
# Cortical Thickness Standard Deviation of RightMiddleTemporal    0
# Volume (WM Parcellation) of FourthVentricle                     0
# Length: 371, dtype: int64

# %% [markdown]
# ## Correlation

# %%
# # Step 1: Calculate Correlation
# correlation_matrix = concatenated_df.corr()

# # Step 2: Draw Correlation Matrix Heatmap
# plt.figure(figsize=(8, 6))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# plt.title('Correlation Matrix Heatmap')
# plt.show()

# %%
test_df['Diagnosis'].value_counts()
# Out:
# LMCI    562
# CN      417
# AD      342
# EMCI    310
# SMC     106
# Name: Diagnosis, dtype: int64

# %%
# Define a custom color palette
palette = ['blue', 'green', 'red', 'purple', 'orange']
# Create the countplot with the custom palette
plt.figure(figsize=(10, 6))
sns.countplot(x='Diagnosis', data=test_df, palette=palette)
# Add labels and title
plt.title('Frequency of Target Class')
plt.xlabel('Target Class')
plt.ylabel('Frequency')
plt.show()
# Out:
# <ipython-input-274-21125b6c6491>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Diagnosis', data=test_df, palette=palette)

# %% [markdown]
# # Data Split

# %%
concatenated_df["Test_data"].value_counts()
# Out:
# 0    1390
# 1     347
# Name: Test_data, dtype: int64

# %%
# Create the countplot with the custom palette
plt.figure(figsize=(10, 6))
sns.countplot(x='Test_data', data=test_df, palette=palette)
# Add labels and title
plt.title('Distribution of data into training and testing')
plt.xlabel('Target Class')
plt.ylabel('Frequency')
plt.show()
# Out:
# <ipython-input-276-ccf49e981e2c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Test_data', data=test_df, palette=palette)
# <ipython-input-276-ccf49e981e2c>:3: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.countplot(x='Test_data', data=test_df, palette=palette)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the aesthetic style of the plots
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(x='Test_data', data=test_df, palette=palette)
# Add a title and axis labels with increased font sizes for improved readability
plt.title('Distribution of Data into Training and Testing', fontsize=16)
plt.xlabel('Target Class', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Display the plot
plt.show()
# Out:
# <ipython-input-277-a9ca3337696c>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Test_data', data=test_df, palette=palette)
# <ipython-input-277-a9ca3337696c>:7: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.countplot(x='Test_data', data=test_df, palette=palette)

# %% [markdown]
# ## Random forest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE  # Importing SMOTE
import matplotlib.pyplot as plt

# Assuming concatenated_df is already imported

# Step 1: Separate the target class
train_data = concatenated_df[concatenated_df['Test_data'] == 0]
test_data = concatenated_df[concatenated_df['Test_data'] == 1]

# Step 2: Split training and testing sets into features (X) and target variable (y)
X_train = train_data.drop(['RID', 'Test_data', 'Diagnosis'], axis=1)
y_train = train_data['Diagnosis']

X_test = test_data.drop(['RID', 'Test_data', 'Diagnosis'], axis=1)
y_test = test_data['Diagnosis']

# Step 3: Balancing classes using SMOTE
smote = SMOTE(random_state=42)  # Using SMOTE for over-sampling
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Step 4: Visualize the distribution of the target class after SMOTE
plt.figure(figsize=(8, 6))
colors = ['red', 'black', 'pink', 'blue']  # Define a custom color palette
y_train_resampled.value_counts().plot(kind='bar', color=colors, edgecolor='black')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.title('Distribution of Target Class after SMOTE')
plt.xticks(rotation=45)
plt.show()

# Step 5: Optionally, split the resampled training data into train and validation sets
X_train_final, X_val, y_train_final, y_val = train_test_split(X_train_resampled, y_train_resampled, test_size=0.2, random_state=42)

# Scaling the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_final)  # Make sure to scale the resampled data
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# Creating and fitting the model
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train_scaled, y_train_final)  # Fit the model on the resampled and scaled training data

# Making predictions
y_pred = model.predict(X_test_scaled)

# Evaluating the model
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
from sklearn.metrics import classification_report

# Generate Classification Report
classification_rep = classification_report(y_test, y_pred)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.7060518731988472
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.79      0.76        62
#            1       0.84      0.62      0.71        84
#            2       0.60      0.92      0.72        63
#            3       0.84      0.66      0.74       122
#            4       0.23      0.38      0.29        16
#
#     accuracy                           0.71       347
#    macro avg       0.65      0.67      0.64       347
# weighted avg       0.75      0.71      0.71       347

# %% [markdown]
# ### evaluation graphs

# %%
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Convert multiclass problem into binary classification (One vs Rest)
from sklearn.preprocessing import label_binarize

y_test_binary = label_binarize(y_test, classes=[0, 1, 2, 3])  # Assuming you have 4 classes
y_pred_proba = model.predict_proba(X_test_scaled)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):  # Assuming you have 4 classes
    fpr[i], tpr[i], _ = roc_curve(y_test_binary[:, i], y_pred_proba[:, i])
    roc_auc[i] = roc_auc_score(y_test_binary[:, i], y_pred_proba[:, i])

# Plot ROC Curves
plt.figure(figsize=(8, 6))
for i in range(4):  # Assuming you have 4 classes
    plt.plot(fpr[i], tpr[i], lw=2, label='ROC curve (area = %0.2f) for class %d' % (roc_auc[i], i))

plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[49  0  3 10  0]
#  [ 1 52  8  3 20]
#  [ 3  0 58  2  0]
#  [14  2 26 80  0]
#  [ 0  8  2  0  6]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot Confusion Matrix with a different color scheme
plt.figure(figsize=(8, 6))
# Using the 'coolwarm' color scheme instead of 'Blues'
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm')

# Adding titles and labels for clarity
plt.title('Confusion Matrix', fontsize=16)
plt.xlabel('Predicted Labels', fontsize=14)
plt.ylabel('True Labels', fontsize=14)

# Display the heatmap
plt.show()

# %%
from sklearn.metrics import classification_report

# Generate Classification Report
classification_rep = classification_report(y_test, y_pred)
print("Classification Report:")
print(classification_rep)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.79      0.76        62
#            1       0.84      0.62      0.71        84
#            2       0.60      0.92      0.72        63
#            3       0.84      0.66      0.74       122
#            4       0.23      0.38      0.29        16
#
#     accuracy                           0.71       347
#    macro avg       0.65      0.67      0.64       347
# weighted avg       0.75      0.71      0.71       347

# %%
recall_scores = {}
support_scores = {}
precision_scores = {}  # Add this line to store precision scores

for line in classification_rep.split('\n')[2:7]:  # Extracting scores for each class
    values = line.split()
    if values:
        class_label = int(values[0])
        recall_scores[class_label] = float(values[2])  # Recall score
        support_scores[class_label] = int(values[4])  # Support score

        # Extract precision score (assuming it's the first value)
        precision_scores[class_label] = float(values[1])

# Plot Precision, Recall, and Support in a single row
plt.figure(figsize=(18, 6))

# Plot Precision
plt.subplot(1, 3, 1)
plt.bar(precision_scores.keys(), precision_scores.values(), color='blue')
plt.xlabel('Classes')
plt.ylabel('Precision')
plt.title('Precision for Each Class')
plt.xticks(list(precision_scores.keys()))
plt.ylim(0, 1)  # Limit y-axis to range from 0 to 1 for precision score

# Plot Recall (unchanged)
plt.subplot(1, 3, 2)
plt.bar(recall_scores.keys(), recall_scores.values(), color='green')
plt.xlabel('Classes')
plt.ylabel('Recall')
plt.title('Recall for Each Class')
plt.xticks(list(recall_scores.keys()))
plt.ylim(0, 1)  # Limit y-axis to range from 0 to 1 for recall score

# Plot Support (unchanged)
plt.subplot(1, 3, 3)
plt.bar(support_scores.keys(), support_scores.values(), color='orange')
plt.xlabel('Classes')
plt.ylabel('Support')
plt.title('Support for Each Class')
plt.xticks(list(support_scores.keys()))

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# ### cross validation of random forest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# SMOTE and train-test split code as before

# Scaling the features
scaler = StandardScaler()
X_train_resampled_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled = scaler.transform(X_test)

# Creating and fitting the model
model = RandomForestClassifier()

# Implementing cross-validation
cv_scores = cross_val_score(model, X_train_resampled_scaled, y_train_resampled, cv=5, scoring='accuracy')

# Printing the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean cross-validation score:", cv_scores.mean())

# Fitting the model to the entire resampled training set
model.fit(X_train_resampled_scaled, y_train_resampled)

# Making predictions on the test set
y_pred = model.predict(X_test_scaled)

# Evaluating the model on the test set
accuracy = accuracy_score(y_test, y_pred)
print("Test set accuracy:", accuracy)
# Out:
# Cross-validation scores: [0.92272727 0.92727273 0.76818182 0.70227273 0.88863636]
# Mean cross-validation score: 0.8418181818181818
# Test set accuracy: 0.7146974063400576

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.preprocessing import StandardScaler

# Initializing the StandardScaler
scaler = StandardScaler()

# Scaling the training, validation, and test sets
X_train_scaled = scaler.fit_transform(X_train_final)  # Make sure to scale the resampled data
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# Creating and fitting the model
from sklearn.tree import DecisionTreeClassifier

# Initializing the DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=42)

# Fitting the model on the resampled and scaled training data
model.fit(X_train_scaled, y_train_final)

# Making predictions on the test set
y_pred = model.predict(X_test_scaled)

# Evaluating the model
from sklearn.metrics import accuracy_score

# Calculating the accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

from sklearn.metrics import classification_report

# Generating and printing the classification report
classification_rep = classification_report(y_test, y_pred)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.7089337175792507
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.71        62
#            1       0.82      0.82      0.82        84
#            2       0.65      0.67      0.66        63
#            3       0.73      0.69      0.71       122
#            4       0.32      0.38      0.34        16
#
#     accuracy                           0.71       347
#    macro avg       0.64      0.66      0.65       347
# weighted avg       0.71      0.71      0.71       347

# %%
recall_scores = {}
support_scores = {}
precision_scores = {}  # Add this line to store precision scores

for line in classification_rep.split('\n')[2:7]:  # Extracting scores for each class
    values = line.split()
    if values:
        class_label = int(values[0])
        recall_scores[class_label] = float(values[2])  # Recall score
        support_scores[class_label] = int(values[4])  # Support score

        # Extract precision score (assuming it's the first value)
        precision_scores[class_label] = float(values[1])

# Plot Precision, Recall, and Support in a single row
plt.figure(figsize=(18, 6))

# Plot Precision
plt.subplot(1, 3, 1)
plt.bar(precision_scores.keys(), precision_scores.values(), color='blue')
plt.xlabel('Classes')
plt.ylabel('Precision')
plt.title('Precision for Each Class')
plt.xticks(list(precision_scores.keys()))
plt.ylim(0, 1)  # Limit y-axis to range from 0 to 1 for precision score

# Plot Recall (unchanged)
plt.subplot(1, 3, 2)
plt.bar(recall_scores.keys(), recall_scores.values(), color='green')
plt.xlabel('Classes')
plt.ylabel('Recall')
plt.title('Recall for Each Class')
plt.xticks(list(recall_scores.keys()))
plt.ylim(0, 1)  # Limit y-axis to range from 0 to 1 for recall score

# Plot Support (unchanged)
plt.subplot(1, 3, 3)
plt.bar(support_scores.keys(), support_scores.values(), color='orange')
plt.xlabel('Classes')
plt.ylabel('Support')
plt.title('Support for Each Class')
plt.xticks(list(support_scores.keys()))

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# ### cross validation of decision tree

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# SMOTE and train-test split code as before

# Scaling the features
scaler = StandardScaler()
X_train_resampled_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled = scaler.transform(X_test)

# Initializing the DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=42)


# Implementing cross-validation
cv_scores = cross_val_score(model, X_train_resampled_scaled, y_train_resampled, cv=5, scoring='accuracy')

# Printing the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean cross-validation score:", cv_scores.mean())

# Fitting the model to the entire resampled training set
model.fit(X_train_resampled_scaled, y_train_resampled)

# Making predictions on the test set
y_pred = model.predict(X_test_scaled)

# Evaluating the model on the test set
accuracy = accuracy_score(y_test, y_pred)
print("Test set accuracy:", accuracy)
# Out:
# Cross-validation scores: [0.83863636 0.82954545 0.74318182 0.72045455 0.85      ]
# Mean cross-validation score: 0.7963636363636364
# Test set accuracy: 0.7175792507204611

# %% [markdown]
# ## Logestic Regression

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_final)  # Make sure to scale the resampled data
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# Creating and fitting the model
from sklearn.linear_model import LogisticRegression

# Create a Logistic Regression model
model = LogisticRegression(random_state=42, max_iter=1000)  # Increased max_iter for convergence
model.fit(X_train_scaled, y_train_final)  # Fit the model on the resampled and scaled training data

# Making predictions
y_pred = model.predict(X_test_scaled)

# Evaluating the model
from sklearn.metrics import accuracy_score

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

from sklearn.metrics import classification_report

# Generate Classification Report
classification_rep = classification_report(y_test, y_pred)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.6138328530259366
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70        62
#            1       0.71      0.69      0.70        84
#            2       0.48      0.51      0.50        63
#            3       0.68      0.62      0.65       122
#            4       0.10      0.12      0.11        16
#
#     accuracy                           0.61       347
#    macro avg       0.53      0.53      0.53       347
# weighted avg       0.62      0.61      0.62       347

# %%
recall_scores = {}
support_scores = {}
precision_scores = {}  # Add this line to store precision scores

for line in classification_rep.split('\n')[2:7]:  # Extracting scores for each class
    values = line.split()
    if values:
        class_label = int(values[0])
        recall_scores[class_label] = float(values[2])  # Recall score
        support_scores[class_label] = int(values[4])  # Support score

        # Extract precision score (assuming it's the first value)
        precision_scores[class_label] = float(values[1])

# Plot Precision, Recall, and Support in a single row
plt.figure(figsize=(18, 6))

# Plot Precision
plt.subplot(1, 3, 1)
plt.bar(precision_scores.keys(), precision_scores.values(), color='blue')
plt.xlabel('Classes')
plt.ylabel('Precision')
plt.title('Precision for Each Class')
plt.xticks(list(precision_scores.keys()))
plt.ylim(0, 1)  # Limit y-axis to range from 0 to 1 for precision score

# Plot Recall (unchanged)
plt.subplot(1, 3, 2)
plt.bar(recall_scores.keys(), recall_scores.values(), color='green')
plt.xlabel('Classes')
plt.ylabel('Recall')
plt.title('Recall for Each Class')
plt.xticks(list(recall_scores.keys()))
plt.ylim(0, 1)  # Limit y-axis to range from 0 to 1 for recall score

# Plot Support (unchanged)
plt.subplot(1, 3, 3)
plt.bar(support_scores.keys(), support_scores.values(), color='orange')
plt.xlabel('Classes')
plt.ylabel('Support')
plt.title('Support for Each Class')
plt.xticks(list(support_scores.keys()))

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# ### cross validation of logestic regression

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# SMOTE and train-test split code as before

# Scaling the features
scaler = StandardScaler()
X_train_resampled_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled = scaler.transform(X_test)

# Initializing the DecisionTreeClassifier
model = LogisticRegression(random_state=42, max_iter=1000)


# Implementing cross-validation
cv_scores = cross_val_score(model, X_train_resampled_scaled, y_train_resampled, cv=5, scoring='accuracy')

# Printing the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean cross-validation score:", cv_scores.mean())

# Fitting the model to the entire resampled training set
model.fit(X_train_resampled_scaled, y_train_resampled)

# Making predictions on the test set
y_pred = model.predict(X_test_scaled)

# Evaluating the model on the test set
accuracy = accuracy_score(y_test, y_pred)
print("Test set accuracy:", accuracy)
# Out:
# Cross-validation scores: [0.86818182 0.82727273 0.72954545 0.76590909 0.91590909]
# Mean cross-validation score: 0.8213636363636363
# Test set accuracy: 0.6426512968299711
